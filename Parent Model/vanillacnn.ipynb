# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  

import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
print(f"GPUs visible: {len(gpus)}", ("✅ Using GPU" if gpus else "⚠️ No GPU (running on CPU)"))

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models, Sequential, Input


DATASET_PATH = "/kaggle/input/skin-cancer-mnist-ham10000/"
meta_csv = os.path.join(DATASET_PATH, "HAM10000_metadata.csv")
if not os.path.exists(meta_csv):
    raise FileNotFoundError("HAM10000_metadata.csv not found. Make sure you added the Kaggle dataset to this notebook.")

metadata = pd.read_csv(meta_csv)


all_image_dir = [
    os.path.join(DATASET_PATH, "HAM10000_images_part_1"),
    os.path.join(DATASET_PATH, "HAM10000_images_part_2")
]

def get_image_path(image_id):
    for d in all_image_dir:
        path = os.path.join(d, image_id + ".jpg")
        if os.path.exists(path):
            return path
    return None

metadata['image_path'] = metadata['image_id'].apply(get_image_path)

before = len(metadata)
metadata = metadata.dropna(subset=['image_path']).reset_index(drop=True)
after = len(metadata)
print(f"Found image files for {after}/{before} rows.")


le = LabelEncoder()
metadata['label'] = le.fit_transform(metadata['dx'])  # 7 classes in HAM10000
num_classes = metadata['label'].nunique()
print("Classes:", dict(zip(le.classes_, range(len(le.classes_)))))


train_df, val_df = train_test_split(
    metadata[['image_path', 'label']],
    test_size=0.2,
    stratify=metadata['label'],
    random_state=42
)
print(f"Train: {len(train_df)}  |  Val: {len(val_df)}")


AUTOTUNE = tf.data.AUTOTUNE
IMG_SIZE = 128
BATCH_SIZE = 32

def preprocess_image(file_path, label, augment=False):
    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32) / 255.0
    if augment:
        img = tf.image.random_flip_left_right(img)
        img = tf.image.random_flip_up_down(img)
        # light color jitter
        img = tf.image.random_brightness(img, max_delta=0.05)
        img = tf.image.random_contrast(img, lower=0.95, upper=1.05)
    return img, label

def make_ds(df, training=False):
    ds = tf.data.Dataset.from_tensor_slices((df['image_path'].values, df['label'].values))
    if training:
        ds = ds.shuffle(min(len(df), 2000), reshuffle_each_iteration=True)
        ds = ds.map(lambda f, y: preprocess_image(f, y, augment=True), num_parallel_calls=AUTOTUNE)
    else:
        ds = ds.map(lambda f, y: preprocess_image(f, y, augment=False), num_parallel_calls=AUTOTUNE)
    ds = ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)
    return ds

train_ds = make_ds(train_df, training=True)
val_ds   = make_ds(val_df,   training=False)


model = Sequential([
    Input(shape=(IMG_SIZE, IMG_SIZE, 3)),
    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(128, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()


EPOCHS = 30
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    verbose=1
)


plt.figure()
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.legend(); plt.xlabel("Epochs"); plt.ylabel("Accuracy"); plt.title("Accuracy")

plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend(); plt.xlabel("Epochs"); plt.ylabel("Loss"); plt.title("Loss")
plt.show()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758042757.455277      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758042757.509151      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# GPUs visible: 1 ✅ Using GPU
# Found image files for 10015/10015 rows.
# Classes: {'akiec': 0, 'bcc': 1, 'bkl': 2, 'df': 3, 'mel': 4, 'nv': 5, 'vasc': 6}
# Train: 8012  |  Val: 2003
# I0000 00:00:1758042780.868669      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ...

# %%
from sklearn.metrics import classification_report, f1_score

# Get true labels and predictions on validation set
y_true = []
y_pred = []

for images, labels in val_ds:
    preds = model.predict(images, verbose=0)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(preds, axis=1))

# Compute F1 scores
macro_f1 = f1_score(y_true, y_pred, average='macro')
weighted_f1 = f1_score(y_true, y_pred, average='weighted')

print("Macro F1:", macro_f1)
print("Weighted F1:", weighted_f1)

# Optional: detailed per-class report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=le.classes_))
# Out:
# Macro F1: 0.5074160923921495
# Weighted F1: 0.7436929046654455
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        akiec       0.41      0.38      0.40        65
#          bcc       0.46      0.75      0.57       103
#          bkl       0.55      0.42      0.47       220
#           df       0.75      0.13      0.22        23
#          mel       0.51      0.27      0.36       223
#           nv       0.86      0.93      0.89      1341
#         vasc       0.73      0.57      0.64        28
#
#     accuracy                           0.76      2003
#    macro avg       0.61      0.49      0.51      2003
# weighted avg       0.75      0.76      0.74      2003

# %%
def predict_image(model, img_path, img_size=(128,128)):
    from tensorflow.keras.preprocessing import image
    import numpy as np
    import matplotlib.pyplot as plt

    img = image.load_img(img_path, target_size=img_size)
    img_array = image.img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    plt.figure(figsize=(4,4))
    plt.imshow(image.load_img(img_path))  
    plt.axis("off")
    plt.title("Input Image")
    plt.show()

    preds = model.predict(img_array)[0]  # shape = (7,)

    for i, prob in enumerate(class_names):
        print(f"{class_names[i]:5s} : {preds[i]:.4f}")

    final_class = class_names[np.argmax(preds)]
    print("\n✅ Final Prediction:", final_class)
    return final_class

# %%
predict_image(model, "/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024306.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 691ms/step
# akiec : 0.0000
# bcc   : 0.0000
# bkl   : 0.0000
# df    : 0.0000
# mel   : 0.0000
# nv    : 1.0000
# vasc  : 0.0000
#
# ✅ Final Prediction: nv
# 'nv'
